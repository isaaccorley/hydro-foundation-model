# %%
from src.datasets.marida import MARIDA, MARIDADataModule

ds = MARIDA(root="./data/MARIDA", split="train", bands="rgb")

# %%
ds.cmap

# %%
sample = ds[70]
for k, v in sample.items():
    print(k, v.shape, v.dtype, v.min(), v.max())

sample["mask"].unique()
# Out:
# image torch.Size([3, 256, 256]) torch.float32 tensor(0.0053) tensor(0.0387)
# mask torch.Size([256, 256]) torch.int64 tensor(0) tensor(10)
# tensor([ 0, 10])

# %%
ds.plot(ds[70])
